# %%
# %matplotlib inline

from __future__ import print_function
import numpy as np
import theano
from scipy.misc import imresize,imread
import matplotlib.pyplot as plt

# %%
w = np.random.rand(3,2)
W= theano.shared(np.zeros((3,2)))
print(W.get_value())
W.set_value(w)                 
print(W.get_value())
# Out:
# [[ 0.  0.]
#  [ 0.  0.]
#  [ 0.  0.]]
# [[ 0.84003987  0.81642656]
#  [ 0.96801544  0.60435466]
#  [ 0.88340166  0.03927821]]

# %%
# !wget http://placekitten.com.s3.amazonaws.com/homepage-samples/408/287.jpg
# !wget https://upload.wikimedia.org/wikipedia/commons/f/fd/Siberian_Husky_Dog_5.jpg

cat = imresize(imread('287.jpg'),[231,231])
dog = imresize(imread('Siberian_Husky_Dog_5.jpg'),[231,231])
    
plt.subplot(121)    
plt.imshow(cat)
plt.subplot(122)
plt.imshow(dog)
# Out:
# --2016-12-24 15:41:20--  http://placekitten.com.s3.amazonaws.com/homepage-samples/408/287.jpg
# Resolving placekitten.com.s3.amazonaws.com... 54.231.81.234
# Connecting to placekitten.com.s3.amazonaws.com|54.231.81.234|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 16361 (16K) [image/jpeg]
# Saving to: ‘287.jpg.4’
#
# 287.jpg.4            88%[================>   ]  14.09K  28.7KB/s               287.jpg.4           100%[===================>]  15.98K  32.2KB/s    in 0.5s
#
# 2016-12-24 15:41:21 (32.2 KB/s) - ‘287.jpg.4’ saved [16361/16361]
#
# --2016-12-24 15:41:21--  https://upload.wikimedia.org/wikipedia/commons/f/fd/Siberian_Husky_Dog_5.jpg
# Resolving upload.wikimedia.org... 91.198.174.208, 2620:0:862:ed1a::2:b
# Connecting to upload.wikimedia.org|91.198.174.208|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 912693 (891K) [image/jpeg]
# Saving to: ‘Siberian_Husky_Dog_5.jpg.2’
#
# sky_Dog_5.jpg.2      95%[==================> ] 855.16K   193KB/s    eta 1s     Siberian_Husky_Dog_ 100%[===================>] 891.30K   203KB/s    in 4.8s
#
# 2016-12-24 15:41:27 (186 KB/s) - ‘Siberian_Husky_Dog_5.jpg.2’ saved [912693/912693]

# %%
from sklearn_theano.feature_extraction import OverfeatClassifier
clf = OverfeatClassifier(top_n=5)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-6-5e458fb42205> in <module>()
# ----> 1 from sklearn_theano.feature_extraction import OverfeatClassifier
#       2 clf = OverfeatClassifier(top_n=5)
#
# ImportError: No module named 'sklearn_theano'
